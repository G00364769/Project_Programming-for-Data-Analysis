# %% [markdown]
# ### Project 2018

# %% [markdown]
# Choose a real-world phenomenon that can be measured and for which you could collect at least one-hundred data points across at least four different variables

# %% [markdown]
# ***My project is to create the dataset to check how was the the job market in 2016 to 2018***
#
# what kind of job people are doing and which filed people are getting more job,What are the age group and how much money they are geeting.And who is geetting more job (Male or Female)
#
# Below are the my variable for data set
#
# ***Year*** ,***Job*** ,***Age***, ***Gender***,***Salary***

# %%
#  modules we need:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
#Number of man as N
N=300
#same set of numbers will appear every time
np.random.seed(1234)
# Creating first variable (Year)
# from 2016 to 2018  generate 
Year=['2016', '2017','2018']
Year = np.random.choice(Year,N)
#Year

# %%
plt.hist(Year, color='g')
plt.ylabel('Number of Man') # labelling y axis
plt.xlabel('Year') # labelling x axis
plt.show()

# %%
# Creating Second variable (job)

#Job=np.random.randint(0, 7, 100)# 0= min ,7 is max and size=100
#Job
# creating a number of  jobtypes 
#same set of numbers will appear every time
np.random.seed(1234)
Jobtypes=['Doctors', 'IT Engineer','Scientist','Research','Administrator']
Job=np.random.choice(Jobtypes,N) # size is 300
#Job

# %%
plt.hist(Job, color='g')
plt.ylabel('Number of Man') # labelling y axis
plt.xlabel('Type of job') # labelling x axis
plt.show()

# %% [markdown]
# When i am comparing in total 300 record i can see the highest result is for it engineer and lowest is Research youth so i can tell most number of peoplr are getting job in it field and adminstrator field

# %%
from scipy.stats import norm
# Creating Third variable (Age)
#same set of numbers will appear every time
np.random.seed(200)
Age= np.random.randint(18,51,N)#min age 18 max age 50  and size is 100
#Age

# %%
#plt.hist(Age, color='y')
#plt.ylabel('Number of Man') # labelling y axis
#plt.show()

# %%
# Creating Fourth variable (Gender)
#same set of numbers will appear every time
np.random.seed(143)
#Generate a uniform random sample from Gender of size N with replacement:
Gender = ['Male', 'Female']
#Generates a random sample from a given 1-D array
Gender = np.random.choice(Gender,N) # size is N

# %%
#Generate Hist 
plt.hist(Gender, color='b')
plt.ylabel('Number of Man') # labelling y axis
plt.xlabel('Gender') # labelling x axis
plt.show()

# %% [markdown]
# As per record Male is getting more job compare to female.

# %%
# Creating Fifth variable (Salary)
#same set of numbers will appear every time
np.random.seed(123)
# Random hours person work in ireland 6 to 12 hours
hours=np.random.randint(6,12,N)
# Random money paid min 10 euro to 20 euro 
money=np.random.randint(10,20,N)
Salary=hours*money
#Salary

# %%
#specifies the mean (Salary),specifies the standard deviation(salary) .
fit = stats.norm.pdf(Salary, np.mean(Salary), np.std(Salary))##this is a fitting indeed
plt.plot(Salary,fit,'.r')
plt.hist(Salary,normed=True,color = 'g') # #use this to draw histogram of your data
plt.xlabel('Daily income') # labelling x axis
plt.show()

# %% [markdown]
# Using hist to put your data info along with the fitted curve,This graph is showing in x cordinate = daily base slaray and y cordinate is combination of mean and standard deviation (that is in red mark in graph)

# %% [markdown]
# ### Synthesise/simulate a data set
#
# ***Adding  all five variable in data frame ***

# %%
# using pandas lib to create data frame
import pandas as pd
Df= pd.DataFrame({"Year":Year,"Job":Job,"Age":Age,"Gender":Gender,"DailyIncome":Salary})

# %%
Df
# Out:
#      Age  DailyIncome  Gender            Job  Year
# 0     44          121    Male       Research  2018
# 1     34          104  Female  Administrator  2017
# 2     22          170  Female  Administrator  2016
# 3     30          136  Female        Doctors  2016
# 4     33          119    Male    IT Engineer  2016
# 5     43          135    Male    IT Engineer  2017
# 6     32          104  Female    IT Engineer  2017
# 7     45          144    Male      Scientist  2017
# 8     43           91    Male       Research  2018
# 9     29          105  Female  Administrator  2018
# 10    24           66    Male  Administrator  2018
# 11    19          105  Female      Scientist  2016
# 12    25          133  Female      Scientist  2016
# 13    45           66  Female        Doctors  2018
# 14    27           78    Male        Doctors  2018
# 15    33          133  Female  Administrator  2018
# 16    19           99  Female        Doctors  2016
# 17    41          165  Female    IT Engineer  2016
# 18    39          160  Female      Scientist  2016
# 19    42           66    Male        Doctors  2017
# 20    25           90  Female       Research  2016
# 21    40          100  Female  Administrator  2017
# 22    31          119    Male      Scientist  2018
# 23    34           90    Male      Scientist  2018
# 24    24          104  Female       Research  2018
# 25    49          100  Female       Research  2016
# 26    50          128    Male        Doctors  2016
# 27    38          120    Male    IT Engineer  2017
# 28    39          102  Female       Research  2018
# 29    18          165  Female        Doctors  2018
# ..   ...          ...     ...            ...   ...
# 270   46          176  Female       Research  2017
# 271   49           90  Female      Scientist  2018
# 272   33          102    Male  Administrator  2017
# 273   30           78  Female  Administrator  2017
# 274   23          133    Male      Scientist  2017
# 275   41           66  Female       Research  2017
# 276   29          130  Female  Administrator  2017
# 277   23          171    Male      Scientist  2016
# 278   37          104  Female        Doctors  2016
# 279   31          198    Male      Scientist  2016
# 280   38          130  Female    IT Engineer  2018
# 281   37          165    Male    IT Engineer  2017
# 282   37           96    Male        Doctors  2016
# 283   25          119    Male        Doctors  2017
# 284   46          128    Male        Doctors  2018
# 285   25          120  Female    IT Engineer  2018
# 286   28          136  Female  Administrator  2018
# 287   46           88    Male      Scientist  2017
# 288   30           99    Male    IT Engineer  2017
# 289   29          128  Female    IT Engineer  2016
# 290   24          112  Female  Administrator  2016
# 291   39           84  Female    IT Engineer  2018
# 292   22          190  Female    IT Engineer  2017
# 293   39           70    Male      Scientist  2018
# 294   37          209  Female  Administrator  2016
# 295   21          143    Male       Research  2016
# 296   36          126    Male    IT Engineer  2018
# 297   26          120    Male        Doctors  2018
# 298   42           78    Male       Research  2017
# 299   48          117    Male      Scientist  2018
#
# [300 rows x 5 columns]

# %% [markdown]
# ### Show different levels of a categorical variable by the color of plot elements:

# %%
#Stacked bar plot with two-level group by
#Just do a normal groupby() and call unstack():

Df.groupby(['Year','Gender'])['Job'].size().unstack().plot(kind='bar',stacked=True)
Df.groupby(['Year','Job'])['Age'].size().unstack().plot(kind='bar',stacked=True)
plt.show()
#Df.groupby(['Year','Job'])['Age'].size()
#Df.groupby(['Year','Gender'])['Job'].size()

# %% [markdown]
# ***Gender VS Job and Year***
#
# In relation to Gender graph 2016 to 2018 i can say male are geeting more job compare to female but if i compare all 3 years record i see every year femail ratio is getting down. But for male 2017 it was high but 2018 it was less compare to 2016,In job related people are getting more jobs in IT Fields and 2017 lots of job in it field, as per three years records reserch youth is increasing from 2016 to 2018 and Administrator,Scientist job market is down

# %% [markdown]
#  Checking Number of count for JOB

# %%
Df['Job'].value_counts()
# Out:
# IT Engineer      75
# Administrator    60
# Doctors          58
# Scientist        55
# Research         52
# Name: Job, dtype: int64

# %% [markdown]
# Checking Number of count for Male and Female

# %%
Df['Gender'].value_counts()
# Out:
# Male      168
# Female    132
# Name: Gender, dtype: int64

# %%
# While describing data set Gender and Job were not appering because its in string form.
#Number each group from 0 to the number of groups - 1.

# %%
Df['Gender'] = Df.groupby('Gender').ngroup()
Df['DailyIncome'] = Df.groupby('DailyIncome').ngroup()
Df['Job'] = Df.groupby('Job').ngroup()
Df['Year'] = Df.groupby('Year').ngroup()

# %%
Df.describe()
# Out:
#               Age  DailyIncome      Gender         Job        Year
# count  300.000000   300.000000  300.000000  300.000000  300.000000
# mean    33.926667    23.896667    0.560000    1.946667    0.963333
# std      9.612629    13.927643    0.497216    1.379674    0.798403
# min     18.000000     0.000000    0.000000    0.000000    0.000000
# 25%     25.000000    12.000000    0.000000    1.000000    0.000000
# 50%     34.000000    24.000000    1.000000    2.000000    1.000000
# 75%     42.000000    35.000000    1.000000    3.000000    2.000000
# max     50.000000    50.000000    1.000000    4.000000    2.000000

# %% [markdown]
# Generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.plot_trisurf, which creates a surface by first finding a set of triangles formed between adjacent points
#__(remember that x, y, and z here are one-dimensional arrays):
ax.plot_trisurf(Df['DailyIncome'],Df['Gender'],Age,linewidth=0.2, antialiased=True)
ax.set_title('surface')
# Defining lable
ax.set_xlabel('DailyIncome')
ax.set_ylabel('Gender')
ax.set_zlabel('Aged')
# Out:
# Text(0.5,0,'Aged')

# %% [markdown]
# ***Feature-Class Relationships***
#
# One approach is to visualize the distribution of attributes for data instances for each class and note and differences. You can generate a matrix of histograms for each attribute and one matrix of histograms for each class value, as follows
#
# The data is grouped by the class attribute (two groups) then a matrix of histograms is created for the attributes is in each group. The result is two images.

# %%
Df.groupby('Gender').hist()
# Out:
# Gender
# 0    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# 1    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %% [markdown]
# ***Feature-Feature Relationships****
#
# The final important relationship to explore is that of the relationships between the attributes.
#
# We can review the relationships between attributes by looking at the distribution of the interactions of each pair of attributes.
# This uses a built function to create a matrix of scatter plots of all attributes versus all attributes. The diagonal where each attribute would be plotted against itself shows the Kernel Density Estimation of the attribute instead.

# %%
#Feature-Feature Relationships
from pandas.plotting import scatter_matrix
scatter_matrix(Df, alpha=0.8, figsize=(16, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016BCC940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000016BE4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000154A7400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000154E0470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001551A390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001551A3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015587080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000155C0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000155F80F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015615F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001565C9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015691E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000156CAEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015707E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000157386A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000015770860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000157AC860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000157E38D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000157F8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001584E160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000015886630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000158C06A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000158FA630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015924E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001595CF60>]],
#       dtype=object)

# %% [markdown]
# ### References
#
# https://stackoverflow.com/questions/22639587/random-seed-what-does-it-do
#
# https://docs.scipy.org/doc/numpy-1.14.1/reference/generated/numpy.random.random_integers.html#numpy.random.random_integers
#
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.random.randint.html
#
# https://docs.python.org/3/library/statistics.html
#
# https://stackoverflow.com/questions/20011494/plot-normal-distribution-with-matplotlib
#
# http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot
#
# https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html
#
# https://machinelearningmastery.com/quick-and-dirty-data-analysis-with-pandas/
